# %%
import pandas as pd
import numpy as np

# %%
data = {
    "group": ["A", "B", "A", "B", "A", "B"],
    "value1": [1, 2, 3, 4, 5, 6],
    "value2": [10, 20, 30, 40, 50, 60]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#   group  value1  value2
# 0     A       1      10
# 1     B       2      20
# 2     A       3      30
# 3     B       4      40
# 4     A       5      50
# 5     B       6      60

# %%
grouped = df.groupby("group").mean()

# %%
grouped
# Out:
#        value1  value2
# group
# A         3.0    30.0
# B         4.0    40.0

# %%
grouped = df.groupby("group").sum()

# %%
grouped
# Out:
#        value1  value2
# group
# A           9      90
# B          12     120

# %%
titanic = pd.read_csv("titanic.csv")
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
ages = titanic['Age']

# %%
ages.shape
# Out:
# (891,)

# %%
age_sex =  titanic[['Age', 'Sex']]

# %%
age_sex.head()
# Out:
#     Age     Sex
# 0  22.0    male
# 1  38.0  female
# 2  26.0  female
# 3  35.0  female
# 4  35.0    male

# %%
above35 = titanic[titanic["Age"] > 35]
above35
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 6              7         0       1
# 11            12         1       1
# 13            14         0       3
# 15            16         1       2
# ..           ...       ...     ...
# 865          866         1       2
# 871          872         1       1
# 873          874         0       3
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# above35_sorted = titanic.loc[titanic["Age"] >= 35].sort_values("Age", ascending=False)

above35_sorted=titanic.loc[titanic['Age'] >= 35].sort_values("Age", ascending=True)
above35_sorted
# Out:
#      PassengerId  Survived  Pclass  \
# 614          615         0       3
# 486          487         1       1
# 230          231         1       1
# 279          280         1       3
# 590          591         0       3
# ..           ...       ...     ...
# 116          117         0       3
# 493          494         0       1
# 96            97         0       1
# 851          852         0       3
# 630          631         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 614                  Brocklebank, Mr. William Alfred    male  35.0      0
# 486  Hoyt, Mrs. Frederick Maxfield (Jane Anne Forby)  female  35.0      1
# 230     Harris, Mrs. Henry Birkhardt (Irene Wallach)  female  35.0      1
# 279                 Abbott, Mrs. Stanton (Rosa Hunt)  female  35.0      1
# 590                             Rintamaki, Mr. Matti    male  35.0      0
# ..                                               ...     ...   ...    ...
# ...

# %%
# pandas의 'isin()' 함수는 DataFrame 열의 각 값이 값 목록 또는 다른 DataFrame 열에 포함되어 있는지 확인하는 메서드입니다.

male_sex = titanic[titanic['Sex'].isin(['female'])]
male_sex
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
class_23 = titanic[(titanic["Pclass"] == 2) | (titanic["Pclass"] == 3)]

# %%
class_23
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...
